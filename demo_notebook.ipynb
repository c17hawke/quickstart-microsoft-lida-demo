# %%
import pandas as pd

path = "./data/housing.csv"

data = pd.read_csv(path)

data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# solution plan
# i.  ..
def plot(data: pd.DataFrame):

     # only modify this section
    plt.figure(figsize=(10, 6))
    sns.histplot(data=data, x='housing_median_age', kde=True, color='blue', alpha=0.5)
    plt.axvline(x=data['housing_median_age'].median(), color='red', linestyle='--', label=f'Median: {data["housing_median_age"].median():,.2f}')
    plt.legend()
    plt.title('What is the distribution of housing_median_age?', wrap=True)
    plt.xlabel('Housing Median Age')
    plt.ylabel('Frequency')
    return plt;

chart = plot(data)

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from lida import Manager, llm

lida = Manager(text_gen = llm("openai")) # palm, cohere ..

# %%
summary = lida.summarize("./data/housing.csv")

summary
# Out:
# {'name': 'housing.csv',
#  'file_name': 'housing.csv',
#  'dataset_description': '',
#  'fields': [{'column': 'longitude',
#    'properties': {'dtype': 'number',
#     'std': 2.0231618362315236,
#     'min': -124.3,
#     'max': -114.55,
#     'samples': [-116.99, -118.1, -115.62],
#     'num_unique_values': 669,
#     'semantic_type': '',
#     'description': ''}},
#   {'column': 'latitude',
#    'properties': {'dtype': 'number',
#     'std': 2.141434460355563,
#     'min': 32.55,
#     'max': 41.92,
#     'samples': [39.38, 39.03, 33.8],
#     'num_unique_values': 660,
#     'semantic_type': '',
#     'description': ''}},
#   {'column': 'housing_median_age',
#    'properties': {'dtype': 'number',
#     'std': 12.467916378686214,
#     'min': 2.0,
#     'max': 52.0,
#     'samples': [48.0, 41.0, 3.0],
#     'num_unique_values': 51,
#     'semantic_type': '',
#     'description': ''}},
#   {'column': 'total_rooms',
#    'properties': {'dtype': 'number',
#     'std': 2227.970479254633,
#     'min': 8.0,
#     'max': 37937.0,
#     'samples': [1240.0, 6603.0, 1899.0],
#     'num_unique_values': 2868,
#     'semantic_type': '',
#     'description': ''}},
#   {'column': 'total_bedrooms',
#    'properties': {'dtype': 'number',
#     'std': 422.2673695326552,
#     'min': 1.0,
#     'max': 5471.0,
#     'samples': [908.0, 712.0, 562.0],
#     'num_unique_values': 1217,
#     'semantic_type': '',
#     'description': ''}},
#   {'column': 'population',
#    'properties': {'dtype': 'number',
#     'std': 1140.739275918484,
#     'min': 3.0,
#     'max': 16122.0,
#     'samples': [1920.0, 1202.0, 2254.0],
#     'num_unique_values': 2225,
#     'semantic_type': '',
#     'description': ''}},
#   {'column': 'households',
#    'properties': {'dtype': 'number',
#     'std': 384.9317181394569,
#     'min': 1.0,
#     'max': 5189.0,
#     'samples': [210.0, 682.0, 1089.0],
#     'num_unique_values': 1174,
#     'semantic_type': '',
#     'description': ''}},
#   {'column': 'median_income',
#    'properties': {'dtype': 'number',
#     'std': 1.9586226746075461,
#     'min': 0.4999,
#     'max': 15.0001,
#     'samples': [4.3676, 2.8971, 6.4265],
#     'num_unique_values': 3721,
#     'semantic_type': '',
#     'description': ''}},
#   {'column': 'median_house_value',
#    'properties': {'dtype': 'number',
#     'std': 117470.76461350403,
#     'min': 14999.0,
#     'max': 500001.0,
#     'samples': [483300.0, 229700.0, 83800.0],
#     'num_unique_values': 2245,
#     'semantic_type': '',
#     'description': ''}},
#   {'column': 'ocean_proximity',
#    'properties': {'dtype': 'category',
#     'samples': ['<1H OCEAN', 'ISLAND', 'NEAR BAY'],
#     'num_unique_values': 5,
#     'semantic_type': '',
#     'description': ''}}],
#  'field_names': ['longitude',
#   'latitude',
#   'housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'population',
#   'households',
#   'median_income',
#   'median_house_value',
#   'ocean_proximity']}

# %%
pd.DataFrame(summary["fields"])
# Out:
#                column                                         properties
# 0           longitude  {'dtype': 'number', 'std': 2.0231618362315236,...
# 1            latitude  {'dtype': 'number', 'std': 2.141434460355563, ...
# 2  housing_median_age  {'dtype': 'number', 'std': 12.467916378686214,...
# 3         total_rooms  {'dtype': 'number', 'std': 2227.970479254633, ...
# 4      total_bedrooms  {'dtype': 'number', 'std': 422.2673695326552, ...
# 5          population  {'dtype': 'number', 'std': 1140.739275918484, ...
# 6          households  {'dtype': 'number', 'std': 384.9317181394569, ...
# 7       median_income  {'dtype': 'number', 'std': 1.9586226746075461,...
# 8  median_house_value  {'dtype': 'number', 'std': 117470.76461350403,...
# 9     ocean_proximity  {'dtype': 'category', 'samples': ['<1H OCEAN',...

# %%
goals = lida.goals(summary, n=3)
pd.DataFrame(goals)
# Out:
#    index                                           question  \
# 0      0    What is the distribution of housing_median_age?
# 1      1  What is the relationship between median_income...
# 2      2            What is the distribution of population?
#
#                                        visualization  \
# 0                    histogram of housing_median_age
# 1  scatter plot of median_income and median_house...
# 2                            histogram of population
#
#                                            rationale
# 0  This tells about the age distribution of house...
# 1  This helps to identify if there is a correlati...
# 2  This helps to understand the population densit...

# %%
from lida.utils import plot_raster

charts = lida.visualize(summary=summary, goal=goals[0])

charts
# Out:
# [ChartExecutorResponse(spec=None, status=True, raster='...', code="import seaborn as sns\nimport pandas as pd\nimport matplotlib.pyplot as plt\n\n# solution plan\n# i.  ..\ndef plot(data: pd.DataFrame):\n\n     # only modify this section\n    plt.figure(figsize=(10,6))\n    sns.histplot(data=data, x='housing_median_age', kde=True, color='blue', alpha=0.5)\n    plt.axvline(x=data['housing_median_age'].median(), color='red', linestyle='--', label='Median Age: {:.2f}'.format(data['housing_median_age'].median()))\n    plt.legend()\n    plt.title('What is the distribution of housing_median_age?', wrap=True)\n    plt.xlabel('Housing Median Age')\n    plt.ylabel('Frequency')\n    return plt;\n\nchart = plot(data)", library='seaborn', error=None)]

# %%
plot_raster(charts[0].raster)
